# %% [markdown]
# # Web Scraping a Car Website

# %% [markdown]
# We are going to scrape data from a Car website https://www.cars.com/shopping/. The main aspects we are going to scrape are Name, Price, Rating and Dealer name. To do this we will be using BeautifulSoup, requests and Pandas library.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = ('https://www.cars.com/shopping/results/?stock_type=new&makes%5B%5D=subaru&models%5B%5D=subaru-outback&list_price_max=&maximum_distance=20&zip=')

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="ep-theme-cars" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title data-suffix=" | Cars.com">New Subaru Outback for Sale Near Me | Cars.com</title>
# <meta content="Shop Subaru Outback vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 3,026 Outback models nationwide." name="description"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="Cars.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="New Subaru Outback for Sale Near Me | Cars.com" property="og:title"/>
# <meta content="https://www.cars.com/shopping/results" property="og:url"/>
# <meta content="Shop Subaru Outback vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 3,026 Outback models nationwide." property="og:description"/>
# <meta content="https://graphics.cars.com/images/core/logo.png" property="og:image"/>
# <meta content="290349283473" property="fb:app_id"/>
# <meta content="app-id=353263352" name="apple-itunes-app"/>
# <meta content="@carsdotcom" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="New Subaru Outback for Sale Near Me | Cars.com" name="twitter:title"/>
# <meta content="Shop Subaru Outback vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 3,026 Outback models nationwide." name="twitter:description"/>
# <meta content="https://graphics.cars.com/images/core/logo.png" name="twitter:image"/>
# <script type="application/ld+json">{"@context":"http://www.schema.org","@type":"WebSite","name":"Cars.com","url":"https://www.cars.com/"}</script>
# <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <style>
# a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,button,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,main,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{border:0;font-weight:400;margin:0;padding:0;vertical-align:baseline}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block}body{line-height:1}ol,ul{list-style:none}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:"";content:none}table{border-collapse:collapse;border-spacing:0}.sds-checkbox,.sds-radio{display:inline;position:relative}.sds-checkbox:after,.sds-radio:after{content:"\a";white-space:pre}.sds-checkbox+.sds-checkbox,.sds-checkbox+.sds-radio,.sds-radio+.sds-checkbox,.sds-radio+.sds-radio{margin-top:16px}.sds-checkbox .sds-input,.sds-radio .sds-input{height:20px;left:0;opacity:0;position:absolute;top:0;width:20px}.sds-checkbox .sds-input+.sds-label,.sds-checkbox .sds-input+.sds-legend,.sds-radio .sds-input+.sds-label,.sds-radio .sds-input+.sds-legend{-webkit-user-select:none;-moz-user-select:none;user-select:none}.sds-checkbox .sds-input+.sds-label:before,.sds-checkbox .sds-input+.sds-legend:before,.sds-radio .sds-input+.sds-label:before,.sds-radio .sds-input+.sds-legend:before{border:1px solid #bdbdbd;content:"";height:20px;left:0;position:absolute;top:-.1em;width:20px}.sds-checkbox .sds-input:disabled+.sds-label,.sds-checkbox .sds-input:disabled+.sds-legend,.sds-radio .sds-input:disabled+.sds-label,.sds-radio .sds-input:disabled+.sds-legend{cursor:not-allowed;opacity:.4}.sds-checkbox .sds-input.error+.sds-label:before,.sds-checkbox .sds-input.error+.sds-legend:before,.sds-radio .sds-input.error+.sds-label:before,.sds-radio .sds-input.error+.sds-legend:before{border-color:#c10}.sds-checkbox .sds-input:focus+.sds-label:before,.sds-checkbox .sds-input:focus+.sds-legend:before,.sds-radio .sds-input:focus+.sds-label:before,.sds-radio .sds-input:focus+.sds-legend:before{box-shadow:0 0 0 2px #00bfde}.sds-checkbox .sds-input+.sds-label:after,.sds-checkbox .sds-input+.sds-legend:after,.sds-radio .sds-input+.sds-label:after,.sds-radio .sds-input+.sds-legend:after{border:3px solid #000;border-left:0;border-top:0;content:"";height:12px;left:7px;opacity:0;position:absolute;top:1px;transform:rotate(45deg);width:7px}.sds-inverse .sds-checkbox .sds-input+.sds-label:after,.sds-inverse .sds-checkbox .sds-input+.sds-legend:after,.sds-inverse .sds-radio .sds-input+.sds-label:after,.sds-inverse .sds-radio .sds-input+.sds-legend:after{border-color:#fff}.sds-checkbox .sds-input:checked+.sds-label:after,.sds-checkbox .sds-input:checked+.sds-legend:after,.sds-radio .sds-input:checked+.sds-label:after,.sds-radio .sds-input:checked+.sds-legend:after{opacity:1}.sds-checkbox .sds-label,.sds-checkbox .sds-legend,.sds-radio .sds-label,.sds-radio .sds-legend{cursor:pointer;margin:0;padding:0 0 0 32px;position:relative}.sds-checkbox .error~.sds-label,.sds-checkbox .error~.sds-legend,.sds-radio .error~.sds-label,.sds-radio .error~.sds-legend{color:#c10}.sds-checkbox:focus,.sds-radio:focus{outline:2px solid Highlight}@media(-webkit-min-device-pixel-ratio:0){.sds-checkbox:focus,.sds-radio:focus{outline-color:-webkit-focus-ring-color;outline-style:auto}}.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{max-width:1170px}@media (min-width:768px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{margin:0 auto}}@media (min-width:980px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{display:grid}}html{box-sizing:border-box;height:100%;width:100%}*,:after,:before{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;box-sizing: ...
#
#       </style>
# <style>
# .accordion-group{border-bottom:1px solid #e6e6e6}.accordion-header{align-items:center;display:flex;height:48px;justify-content:space-between;min-height:48px}.accordion-header .accordion-section-title{font-size:16px;width:100%}.accordion-header[aria-expanded=true] .accordion-section-icon{transform:rotate(180deg)}.accordion-panel[aria-hidden=true]{display:none}.accordion-panel[aria-hidden=false]{display:flex;flex-direction:column;padding:0 0 16px}.active-filter-tags{margin:0 16px 16px;position:relative}@media (min-width:768px){.active-filter-tags{margin-right:0}}.active-filter-tags .flex-container{display:flex;flex-direction:row;justify-content:space-between}.active-filter-tags .flex-container .show-more-less{align-content:flex-end;display:flex;flex-direction:row;justify-content:flex-start;margin-top:16px}.active-filter-tags .flex-container .show-more-less .sds-text-field__icon{stroke:#b0c!important;margin-left:5px;margin-top:5px}.active-filter-tags .flex-container .show-more-less span{color:#b0c;cursor:pointer}.active-filter-tags .flex-container .clear-all-filter-tags{margin-right:16px;margin-top:16px}.active-filter-tags .flex-container .clear-all-filter-tags span{color:#b0c;cursor:pointer}.active-filter-tags .active-filter-checkbox{display:none}.active-filter-tags .mobile-filtering-by{margin-bottom:16px}@media (min-width:768px){.active-filter-tags .mobile-filtering-by{display:none}}.branded-canvas{border:1px solid #e6e6e6;box-shadow:inset 0 -1px 0 0 #e6e6e6;height:520px;margin-bottom:24px;position:relative;width:100%}@media (min-width:768px){.branded-canvas{height:343px}}@media (min-width:980px){.branded-canvas{height:343px}}.branded-canvas .branded-canvas-main-container{display:flex;flex-direction:column;height:272px;overflow:hidden;position:relative;width:100%}@media (min-width:768px){.branded-canvas .branded-canvas-main-container{flex-direction:row;height:265px;justify-content:space-between}}.branded-canvas .branded-canvas-main-container .branded-canvas-from{color:#fff;font-size:11px;font-style:italic;left:10px;position:absolute;top:32px;z-index:1}.branded-canvas .branded-canvas-main-container .branded-canvas-logo{height:55px;position:absolute;right:12px;top:10px;width:55px;z-index:1}.branded-canvas .branded-canvas-main-container .branded-canvas-car-container{flex:0 0 45%;height:175px;position:relative;text-align:center;z-index:1}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-car-container{flex:0 0 50%}}.branded-canvas .branded-canvas-main-container .branded-canvas-car-container img{max-width:280px;padding-top:52px;position:inherit}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-car-container img{left:11%;max-width:80%;padding-top:0;position:absolute;top:30%}}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop{display:none}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop{display:flex;justify-content:flex-end}}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .sds-button--secondary-dense .sds-text-field__icon_1{stroke:#532380}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .sds-button--secondary-dense:hover .sds-text-field__icon_1{stroke:#fff;transition:stroke .25s ease}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-1{flex:1 1 50%;margin:16px 8px 16px 0;padding:8px;z-index:3}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-1 .sds-text-field__icon{stroke:#532380;margin-left:4px}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-2{flex:1 1 50%;margin:16px 16px 16px 0;padding:8px;z-index:3}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-2 .sds-text-field__icon{stroke:#fff;margin-left:4px} ...
#
#           </style>
# <script defer="" src="/f7330cd9b0313064f6ae/js/app.js?vsn=d"></script>
# <script id="datadog-config" type="application/json">
#     {
#         "clientToken": "pubd9e029f457b6d51b3d399c5b5c8fa7a4",
#         "applicationId": "c7070c7e-6068-4c84-828a-0e3b134e372d",
#         "site": "datadoghq.com",
#         "service": "cars_web",
#         "sampleRate": 2,
#         "trackInteractions": true
#
#     }
# </script>
# <script id="datadog-global-context" type="application/json">
# {"env":"production","trip_id":""}
# </script>
# <meta content="AGAJRhQACwMJMiYhBVQERSAzHxgmLAA9r3YvRSeEozkCGfKhbARJRONS" name="csrf-token"/>
# </head>
# <div hidden="">
# <span id="new-tab-link">Opens website in a new tab</span>
# </div>
# <body>
# <div class="global-header-container">
# <header class="global-header">
# <section class="container">
# <a class="header-logo" data-activity-rule-type="page-over-page" data-component="header-click" data-linkname="header-home" href="/"><img alt="Cars.com" class="header-logo header-logo__img" src="/images/logo_cars-46214ae902ff93ba8fa2e40fb73dfa02.png?vsn=d"/></a>
# <nav class="">
# <button aria-controls="mobile-menu-section" aria-expanded="false" class="mobile-nav-menu-button" id="mobile-menu-button">
# <div class="mobile-nav-menu-open" data-activity-rule-type="custom" data-linkname="header-menu">
# <svg class="menu-icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#menu"></use></svg>
# <span>Menu</span>
# </div>
# <div class="mobile-nav-menu-close hidden" data-activity-rule-type="custom" data-linkname="header-menu-close">
# <svg class="close-icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#close"></use></svg>
# </div>
# </button>
# <div aria-labelledby="mobile-menu-button" class="global-header-menu-links" id="mobile-menu-section">
# <div class="sds-heading--2 hidden" id="mobile-menu-heading">Menu</div>
# <ul class="header-links-wrapper">
# <li class="header-link"><a class="link-active" data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-buy" data-nav-link="" href="/shopping/">Cars for Sale</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-research" data-nav-link="" href="/research/">Research &amp; Reviews</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-news" data-nav-link="" href="/news/">News &amp; Videos</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="4" data-linkname="header-sell-your-car" data-nav-link="" href="/sell/">Sell Your Car</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="5" data-linkname="header-service" data-nav-link="" href="/auto-repair/">Service &amp; Repair</a></li>
# </ul>
# <ul class="profile-links-wrapper" data-phx-session="SFMyNTY.g2gDaAJhBXQAAAAIZAACaWRtAAAAFHBoeC1GdjB6TzlxRkdhUGc1SE9qZAAMbGl2ZV9zZXNzaW9uaAJkABZsaXN0aW5nX3NlYXJjaF9zZXNzaW9ubggAHv8OkNsi_-BhGsYEBYgABUYA.MsGcRSsE7JSLbzZuS1D49yL0IOv2oShvn5cP0gC4qf8" data-phx-static="SFMyNTY.g2gDaAJhBXQAAAADZAAKYXNzaWduX25ld2pkAAVmbGFzaHQAAAAAZAACaWRtAAAAFHBoeC1GdjB6TzlxRkdhUGc1SE9qbgYA-BhGsYEBYgABUYA.opeUiPS_m1WfGI5bchWgZFPkaGURVdF3gBDDgObiIns" id="phx-Fv0zO9qFGaPg5HOj">
# <li class="authed-profile-link"><a data-activity-rule-type="page-over-page" data-auth-link="" data-component="header-click" data-component-index="1" data-linkname="header-saved-cars" href="/profile/saved-cars/"><svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#heart"></use></svg>Saved Cars (0)</a></li>
# <li class="authed-profile-link"><a data-activity-rule-type="page-over-page" data-auth-link="" data-component="header-click" data-component-index="2" data-linkname="header-saved-searches" href="/profile/saved-searches/"><svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#search"></use></svg>Saved Searches (0)</a></li>
# <li class="authed-profile-link"><a data-activity-rule-type="page-over-page" data-auth-link="" data-component="header-click" data-component-index="3" data-linkname="header-your-garage" href="/profile/your-garage/"><svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#tag"></use></svg>Your Garage (0)</a></li>
# </ul>
# <div class="sign-in-up-out mobile">
# <a class="header-signin" content="Sign in" data-activity-rule-type="page-over-page" data-component="sign-in-start" data-linkname="header-sign-in" href="/signin/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dsubaru%26maximum_distance%3D20%26models%255B%255D%3Dsubaru-outback%26stock_type%3Dnew%26zip%3D">Sign in</a>
# <span class="sign-in-out-divider" role="presentation">/</span>
# <a class="header-signup" content="Sign up" data-activity-rule-type="page-over-page" data-component="sign-up-start" data-linkname="header-sign-up" href="/signup/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dsubaru%26maximum_distance%3D20%26models%255B%255D%3Dsubaru-outback%26stock_type%3Dnew%26zip%3D">Sign up</a>
# </div>
# </div>
# <div id="google-one-tap">
# <div data-client_id="67273791563-90cd8jqav0pgefmmb4l5732bguvbjapi.apps.googleusercontent.com" data-login_uri="/signin/google_callback/" data-moment_callback="trackGoogleOneTap" data-redirect_path="/shopping/results/?redirect_event%5Bsocial_platform%5D=google" id="g_id_onload">
# </div>
# </div>
# </nav>
# </section>
# </header>
# </div>
# <section class="sds-page-container" role="main">
# <div data-qa="notifications-are-here"></div>
# <div data-phx-main="true" data-phx-session="SFMyNTY.g2gDaAJhBXQAAAAIZAACaWRtAAAAFHBoeC1GdjB6TzgzTFV5X2c1SEZCZAAMbGl2ZV9zZXNzaW9uaAJkABZsaXN0aW5nX3NlYXJjaF9zZXNzaW9ubggAHv8OkNsi_....6zSfNiCEJLxnJsqg2Risd3Hu6w54bbqM5x1acl9wcIw" data-phx-static="SFMyNTY.g2gDaAJhBXQAAAADZAAKYXNzaWduX25ld2wAAAACZAANaXNfc2VhcmNoX2JvdGQADGN1cnJlbnRfdXNlcmpkAAVmbGFzaHQAAAAAZAACaWRtAAAAFHBoeC1GdjB6TzgzTFV5X2c1SEZCbgYAwBhGsYEBYgABUYA.pD1VdZIsWGh1C-CJ0UXRBddLS8My8tKlv-07Gc_H0s0" id="phx-Fv0zO83LUy_g5HFB">
# <link as="image" href="https://platform.cstatic-images.com/large/in/v2/24051a28-2efc-5ddf-9e47-860739d4c487/6aaab08c-7cc5-4162-ad68-af02ddf6222f/jFc7dhuai9oSlfsAFsPIvbtyR6k.jpg" rel="preload"/>
# <div aria-modal="true" class="sds-modal aria-modal sds-modal-one lead-form-container" id="srp-lead-form-modal" phx-hook="LeadForm" phx-target="#srp-lead-form-modal">
# <div class="lead-modal sds-modal__content" phx-click="close" phx-target="#srp-lead-form-modal" phx-value-close="false">
# <div class="lead-modal sds-modal__content-head">
# <div class="sds-icon--target btn-close" phx-click="reset" phx-target="#srp-lead-form-modal" role="button">
# <span class="sds-icon">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <div class="lead-modal sds-modal__content-body">
# <div class="dealer-section lead-form-top-anchor" id="dealer-section--">
# <header>
# <h2 class="sds-heading--3 lead-form-heading">Contact seller</h2>
# </header>
# </div>
# <div class="lead-form" id="lead-form-container-">
# <form action="#" data-activity-rule-type="custom" data-index="" data-reset-activity-limit-for="email-lead-error--inline" data-submittype="email-lead-submit-" id="fields-srp-lead-form-modal" method="post" phx-change="change" phx-hook="EmailLeadForm" phx-submit="save_lead" phx-target="#srp-lead-form-modal"><input name="_csrf_token" type="hidden" value="AGAJRhQACwMJMiYhBVQERSAzHxgmLAA9r3YvRSeEozkCGfKhbARJRONS"/>
# <section data-activity-limit="1" data-activity-rule-type="custom" data-conversion-type="email-lead-error--inline" data-errorname="email-lead-error--inline" data-index="">
# <div>
# <div class="sds-field-group">
# <div class="customer-form">
# <div class="first-name">
# <div class="sds-input-container">
# <input class="sds-text-field" id="first_name-modal-" name="lead[first_name]" phx-debounce="blur" placeholder=" " type="text"/>
# <label class="sds-label" for="first_name-modal-">First name</label>
# </div>
# </div>
# <div class="last-name">
# <div class="sds-input-container">
# <input class="sds-text-field" id="last_name-modal-" name="lead[last_name]" phx-debounce="blur" placeholder=" " type="text"/>
# <label class="sds-label" for="last_name-modal-">Last name</label>
# </div>
# </div>
# <div class="email">
# <div class="sds-input-container">
# <input class="sds-text-field" data-emailtype="transact" id="email-modal-" name="lead[email]" phx-debounce="blur" phx-hook="EmailInput" placeholder=" " type="text"/>
# <label class="sds-label" for="email-modal-">Email</label>
# </div>
# </div>
# <div class="phone">
# <div class="sds-input-container">
# <input class="sds-text-field" id="phone-modal-" name="lead[phone]" phx-debounce="blur" phx-hook="PhoneNumber" placeholder=" " type="tel"/>
# <label class="sds-label" for="phone-modal-">Phone (optional)</label>
# </div>
# </div>
# <input id="subject-modal-" name="lead[subject]" type="hidden" value="Ask a question"/>
# <div class="comments">
# <div class="sds-input-container sds-input-container--textarea">
# <textarea class="sds-text-field comment-box" id="comments-modal-" name="lead[comments]" phx-debounce="blur" placeholder=" ">
# </textarea>
# <label class="sds-label" for="comments-modal-">Comments</label>
# </div>
# </div>
# </div>
# <div class="sds-field trade-in hidden">
# <div class="sds-field trade-in-checkbox">
# <div class="sds-checkbox trade-in" phx-click="show_trade_in" phx-target="#srp-lead-form-modal">
# <input class="sds-input" id="trade-in-checkbox-srp-lead-form-modal" type="checkbox"/>
# <label class="sds-label" for="trade-in-checkbox-srp-lead-form-modal">I have a trade in</label>
# </div>
# </div>
# <div class="sds-field-group trade-in-form hidden">
# <div class="make">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" id="fields-srp-lead-form-modal_make_select-modal-" name="lead[trade_in][make]"><optgroup label=""><option selected="" value="">Choose a make</option><option value="ac">AC</option><option value="acura">Acura</option><option value="alfa_romeo">Alfa Romeo</option><option value="american_motors">American Motors</option><option value="am_general">Am General</option><option value="aston_martin">Aston Martin</option><option value="auburn">Auburn</option><option value="audi">Audi</option><option value="austin">Austin</option><option value="austin_healey">Austin-Healey</option><option value="avanti_motors">Avanti Motors</option><option value="bentley">Bentley</option><option value="bmw">BMW</option><option value="bricklin">Bricklin</option><option value="bugatti">Bugatti</option><option value="buick">Buick</option><option value="cadillac">Cadillac</option><option value="checker">Checker</option><option value="chevrolet">Chevrolet</option><option value="chrysler">Chrysler</option><option value="citroen">Citroen</option><option value="daewoo">Daewoo</option><option value="daihatsu">Daihatsu</option><option value="datsun">Datsun</option><option value="delahaye">Delahaye</option><option value="delorean">Delorean</option><option value="desoto">Desoto</option><option value="detomaso">DeTomaso</option><option value="dodge">Dodge</option><option value="eagle">Eagle</option><option value="edsel">Edsel</option><option value="essex">Essex</option><option value="ferrari">Ferrari</option><option value="fiat">FIAT</option><option value="fisker">Fisker</option><option value="ford">Ford</option><option value="franklin">Franklin</option><option value="genesis">Genesis</option><option value="geo">Geo</option><option value="gmc">GMC</option><option value="honda">Honda</option><option value="hudson">Hudson</option><option value="hummer">Hummer</option><option value="hupmobile">Hupmobile</option><option value="hyundai">Hyundai</option><option value="infiniti">INFINITI</option><option value="international">International</option><option value="isuzu">Isuzu</option><option value="jaguar">Jaguar</option><option value="jeep">Jeep</option><option value="jensen">Jensen</option><option value="kaiser">Kaiser</option><option value="karma">Karma</option><option value="kia">Kia</option><option value="koenigsegg">Koenigsegg</option><option value="lamborghini">Lamborghini</option><option value="lancia">Lancia</option><option value="land_rover">Land Rover</option><option value="lasalle">LaSalle</option><option value="lexus">Lexus</option><option value="lincoln">Lincoln</option><option value="lotus">Lotus</option><option value="lucid">Lucid</option><option value="maserati">Maserati</option><option value="maybach">Maybach</option><option value="mazda">Mazda</option><option value="mclaren">McLaren</option><option value="mercedes_benz">Mercedes-Benz</option><option value="mercury">Mercury</option><option value="merkur">Merkur</option><option value="mg">MG</option><option value="mini">MINI</option><option value="mitsubishi">Mitsubishi</option><option value="morgan">Morgan</option><option value="morris">Morris</option><option value="nash">Nash</option><option value="nissan">Nissan</option><option value="oldsmobile">Oldsmobile</option><option value="opel">Opel</option><option value="packard">Packard</option><option value="pagani">Pagani</option><option value="panoz">Panoz</option><option value="peugeot">Peugeot</option><option value="plymouth">Plymouth</option><option value="polestar">Polestar</option><option value="pontiac">Pontiac</option><option value="porsche">Porsche</option><option value="qvale">Qvale</option><option value="ram">RAM</option><option value="renault">Renault</option><option value="rivian">Rivian</option><option value="rolls_royce">Rolls-Royce</option><option value="rover">Rover</option><option value="saab">Saab</option><option value="saleen">Saleen</option><option value="saturn">Saturn</option><option value="scion">Scion</optio ...
# <label class="sds-label" for="make_select-modal-">Make</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="model">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" disabled="" id="fields-srp-lead-form-modal_model_select-modal-" name="lead[trade_in][model]"><optgroup label=""><option selected="" value="">Choose a model</option></optgroup></select>
# <label class="sds-label" for="model_select-modal-">Model</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="year">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" disabled="" id="fields-srp-lead-form-modal_year_select-modal-" name="lead[trade_in][year]"><optgroup label=""><option selected="" value="">Choose a year</option></optgroup></select>
# <label class="sds-label" for="year_select-modal-">Year</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="color">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="color-modal-" name="lead[trade_in][color]" phx-debounce="blur" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="color-modal-">Exterior color</label>
# </div>
# </div>
# <div class="mileage">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="mileage_string-modal-" name="lead[trade_in][mileage_string]" phx-debounce="blur" phx-hook="Mileage" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="mileage_string-modal-">Mileage</label>
# </div>
# </div>
# <div class="vin">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="vin-modal-" name="lead[trade_in][vin]" phx-debounce="blur" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="vin-modal-">VIN (optional)</label>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="sds-field sds-form-module__button">
# <button class="sds-button--fluid" data-activity-rule-type="custom" type="submit">Contact seller</button>
# </div>
# <small class="sds-disclaimer">
# <p>
#
# By clicking here, you authorize Cars.com and its sellers/partners to contact you by text/calls which may include marketing and be by autodialer. Calls may be prerecorded. You also agree to our Privacy Statement. Consent is not required to purchase goods/services.
#
#             </p>
# <p>
# We value your privacy.
# <a data-linkname="privacy-statement" href="/about/privacy/" target="_blank">Cars.com Privacy Statement</a>
# </p>
# </small>
# </div>
# </section>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div data-override-payload="null" phx-hook="LeadSubmissionTracker" phx-target="#srp-lead-form-modal" phx_value_cid="srp-lead-form-modal"></div>
# <div phx-hook="LeadFormPositionAdjustments"></div>
# <div id="auth-completion-listener" phx-hook="AuthCompletionListener"></div>
# <div aria-modal="true" class="sds-modal aria-modal sds-modal-one" data-activity-rule-type="custom" data-analytics-linkname="profiles-modal-close" data-component="profiles-modal" data-hook-callback="close_modal" id="auth-modal" phx-hook="ModalBackdrop" phx-target="#auth-modal">
# <div class="sds-modal__content">
# <div class="sds-modal__content-head">
# <div class="sds-icon--target btn-close" data-activity-rule-type="custom" data-component="profiles-modal" data-linkname="profiles-modal-close" phx-click="close_modal" phx-target="#auth-modal" role="button">
# <span class="sds-icon">
# <svg height="24" width="24"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <div class="sds-modal__content-body">
# <div class="sign-up">
# <h3 class="sds-heading--3 sds-heading--display sds-page-section__title">Create your account</h3>
# <div class="modal-body">
# <p class="sds-page-section__title--sub">
# Sign up access your saved searches anywhere, anytime, and from any device.
#     </p>
# <p class="sds-page-section__title--sub">
# Already have a profile? <a data-activity-rule-type="custom" data-component="profiles-modal" data-linkname="modal-sign-in" href="#" phx-click="sign_in" phx-target="#auth-modal">Sign in</a>.
#     </p>
# <ul class="sds-list social-link-list">
# <li class="social-link">
# <a class="sds-button facebook-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-facebook" href="/signin/fb_go/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dsubaru%26maximum_distance%3D20%26models%255B%255D%3Dsubaru-outback%26redirect_event%255Bevent%255D%3Dsave_search%26redirect_event%255Bname%255D%3Dsearch_live%26redirect_event%255Bsocial_platform%255D%3Dfacebook%26stock_type%3Dnew%26zip%3D">
# <svg class="facebook-svg-icon" height="1365.12" viewbox="0 0 14222 14222" width="1365.12" xmlns="http://www.w3.org/2000/svg">
# <circle cx="7111" cy="7112" fill="#fff" r="7111"></circle>
# <path d="M9879 9168l315-2056H8222V5778c0-562 275-1111 1159-1111h897V2917s-814-139-1592-139c-1624 0-2686 984-2686 2767v1567H4194v2056h1806v4969c362 57 733 86 1111 86s749-30 1111-86V9168z" fill="#1977f3"></path>
# </svg>
#   Sign in with Facebook
# </a>
# </li>
# <li class="social-link">
# <a class="sds-button google-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-google" href="/signin/google_go/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dsubaru%26maximum_distance%3D20%26models%255B%255D%3Dsubaru-outback%26redirect_event%255Bevent%255D%3Dsave_search%26redirect_event%255Bname%255D%3Dsearch_live%26redirect_event%255Bsocial_platform%255D%3Dgoogle%26stock_type%3Dnew%26zip%3D">
# <svg fill="none" height="32" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M28.48 16.2955C28.48 15.3736 28.3973 14.4873 28.2436 13.6364H16V18.665H22.9964C22.695 20.29 21.7791 21.6668 20.4023 22.5886V25.8505H24.6036C27.0618 23.5873 28.48 20.2545 28.48 16.2955Z" fill="#4285F4" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M16 29C19.51 29 22.4527 27.8359 24.6036 25.8505L20.4023 22.5886C19.2382 23.3686 17.7491 23.8295 16 23.8295C12.6141 23.8295 9.74819 21.5427 8.72592 18.47H4.38274V21.8382C6.52183 26.0868 10.9182 29 16 29Z" fill="#34A853" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M8.72591 18.47C8.46591 17.69 8.31818 16.8568 8.31818 16C8.31818 15.1432 8.46591 14.31 8.72591 13.53V10.1618H4.38273C3.50227 11.9168 3 13.9023 3 16C3 18.0977 3.50227 20.0832 4.38273 21.8382L8.72591 18.47Z" fill="#FBBC05" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M16 8.17045C17.9086 8.17045 19.6223 8.82636 20.9696 10.1145L24.6982 6.38591C22.4468 4.28818 19.5041 3 16 3C10.9182 3 6.52183 5.91318 4.38274 10.1618L8.72592 13.53C9.74819 10.4573 12.6141 8.17045 16 8.17045Z" fill="#EA4335" fill-rule="evenodd"></path>
# </svg>
#   Sign in with Google
# </a>
# </li>
# <li class="social-link">
# <a class="sds-button apple-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-google" href="/signin/apple_go/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dsubaru%26maximum_distance%3D20%26models%255B%255D%3Dsubaru-outback%26redirect_event%255Bevent%255D%3Dsave_search%26redirect_event%255Bname%255D%3Dsearch_live%26redirect_event%255Bsocial_platform%255D%3Dapple%26stock_type%3Dnew%26zip%3D">
# <svg height="44px" version="1.1" viewbox="0 0 31 44" width="28px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <title>Apple logo</title>
# <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
# <path d="M15.7099491,14.8846154 C16.5675461,14.8846154 17.642562,14.3048315 18.28274,13.5317864 C18.8625238,12.8312142 19.2852829,11.852829 19.2852829,10.8744437 C19.2852829,10.7415766 19.2732041,10.6087095 19.2490464,10.5 C18.2948188,10.5362365 17.1473299,11.140178 16.4588366,11.9494596 C15.9152893,12.56548 15.4200572,13.5317864 15.4200572,14.5222505 C15.4200572,14.6671964 15.4442149,14.8121424 15.4562937,14.8604577 C15.5166879,14.8725366 15.6133185,14.8846154 15.7099491,14.8846154 Z M12.6902416,29.5 C13.8618881,29.5 14.3812778,28.714876 15.8428163,28.714876 C17.3285124,28.714876 17.6546408,29.4758423 18.9591545,29.4758423 C20.2395105,29.4758423 21.0971074,28.292117 21.9063891,27.1325493 C22.8123013,25.8038779 23.1867451,24.4993643 23.2109027,24.4389701 C23.1263509,24.4148125 20.6743484,23.4122695 20.6743484,20.5979021 C20.6743484,18.1579784 22.6069612,17.0588048 22.7156707,16.974253 C21.4353147,15.1382708 19.490623,15.0899555 18.9591545,15.0899555 C17.5217737,15.0899555 16.3501271,15.9596313 15.6133185,15.9596313 C14.8161157,15.9596313 13.7652575,15.1382708 12.521138,15.1382708 C10.1536872,15.1382708 7.75,17.0950413 7.75,20.7911634 C7.75,23.0861411 8.64383344,25.513986 9.74300699,27.0842339 C10.6851558,28.4129053 11.5065162,29.5 12.6902416,29.5 Z" fill="#FFFFFF" fill-rule="nonzero" id=""></path>
# </g>
# </svg>
#   Sign in with Apple
# </a>
# </li>
# </ul>
# <div class="separator-wrapper">
# <div class="sds-separator"></div>
# <div class="separator-text">Or</div>
# <div class="sds-separator"></div>
# </div>
# <form action="#" method="post" phx-submit="sign_up_continue" phx-target="#auth-modal"><input name="_csrf_token" type="hidden" value="AGAJRhQACwMJMiYhBVQERSAzHxgmLAA9r3YvRSeEozkCGfKhbARJRONS"/>
# <div class="sds-field-group">
# <div class="sds-field email">
# <div class="sds-input-container">
# <input class="sds-text-field" data-emailtype="account" id="user_email" maxlength="255" name="user[email]" phx-hook="EmailInput" placeholder=" " type="text"/>
# <label class="sds-label" for="user_email">Email</label>
# </div>
# </div>
# </div>
# <div class="actions">
# <div class="sds-field">
# <button class="sds-button" type="submit">Continue</button>
# </div>
# </div>
# </form>
# <div class="disclaimer">
# <div class="sds-disclaimer">
# By signing up, you agree to our
# <a data-activity-rule-type="custom" data-component="privacy-statement" data-linkname="privacy-statement" href="/about/privacy/" target="_blank">Privacy Statement</a>
#    and
# <a data-activity-rule-type="custom" data-component="terms-of-service" data-linkname="tos" href="/about/terms/" target="_blank">Terms of Service</a>.
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="sds-page-section listings-page" data-applied-filter-criteria="" data-liveview-pageview="true" data-props='{"selected_refinement":null}' data-search-instance-id="77f4b36e-dfeb-424b-9f36-c44c68de5a4e" data-search-type="general-inventory-search" data-site-activity='{"sort_field":"searchRank1","search_min_price":null,"stock_sub":"","canonical_mmt":"","search_radius":"20","cat":"crossover_midsize","model_group":null,"search_results_on_page":20,"stock_type":"","search_min_year":"","interiorColor":"","search_zip":"","result_per_page":20,"features":"","cpo_indicator":false,"model":"","search_max_year":"","filter_category_value":"","search_model_groups":"","search_stock_type":"new","resultsType":"not_modified","searchCategory":"results","search_make_model_groups":"","search_models":"outback","bodystyle":"","seller_type":"","search_trims":"","listing_ids":["37a40c0b-2c7c-4a5b-a532-b0838b31872b","ecf13d20-b900-495e-b42f-e734398f24b5","61395859-7e64-4ecf-b0d6-7fd58f789208","4a41e9ab-7309-4962-9a56-891b9cc06905","89c1862e-e49f-4c23-963a-f202a7fb8d4f","885ccd23-1706-43c7-a5d6-70b23207e43c","49649106-f6b4-4267-987d-6b8c3dc4bf50","1b372a2f-39c7-427c-b4ea-c484f1b3989d","93784ad2-1a0a-4a4d-84b9-bf3aa6feae63","66ec33b4-1a3f-4218-8290-82e94a2e7d4c","87e52041-6adc-47a6-800f-cee54a93fccb","82a62bb8-46ef-441c-a60f-9f2dd53a8c08","aea44366-36b1-4613-8e32-b720f2c01850","58bd9a59-174f-44da-90d4-91b7b13cf7bb","c50b76fe-a490-4f7c-aede-785b3ce9e26e","a9ccae1e-53bb-4818-a959-087daf130bcc","02bd129c-5018-4032-af4a-b050b1e4b15a","57a6aa72-f07a-4256-be29-25b064d4be3e","7c3846d3-07ed-476e-8841-ab4acf5ddf89","bcba0da0-3b2f-4a50-ae00-cc0c02692843"],"price":"","dealerSearchType":"multiple_dealers","trip_id":null,"web_page_type_from":"","search_make_models":"subaru-outback","exterior_color":"","fuel_type":"","transmission":"","search_instance_id":"","search_max_price":"","total_results":3026,"search_bodystyles":"","vehicleArray":[{"badges":["virtual_appt","home_delivery"],"bodystyle":"SUV","canonical_mmt":"Subaru:Outback:Touring XT","cat":"crossover_midsize","certified_preowned":false,"cpo_indicator":false,"customer_id":"5343485","exterior_color":"Abyss Blue Pearl","fuel_type":"Gasoline","listing_id":"37a40c0b-2c7c-4a5b-a532-b0838b31872b","make":"Subaru","mileage":"1","model":"Outback","msrp":"42778","nvi_program":false,"price":"42778","seller_type":"dealership","sponsored":false,"sponsored_type":"none","stock_sub":"","stock_type":"New","trim":"Touring XT","vin":"4S4BTGPD4N3258072","year":"2022"},{"badges":["virtual_appt","home_delivery"],"bodystyle":"SUV","canonical_mmt":"Subaru:Outback:Premium","cat":"crossover_midsize","certified_preowned":false,"cpo_indicator":false,"customer_id":"3538","exterior_color":"Abyss Blue Pearl","fuel_type":"Gasoline","listing_id":"ecf13d20-b900-495e-b42f-e734398f24b5","make":"Subaru","mileage":"5","model":"Outback","msrp":null,"nvi_program":false,"price":"32646","seller_type":"dealership","sponsored":false,"sponsored_type":"none","stock_sub":"","stock_type":"New","trim":"Premium","vin":"4S4BTADC1N3236720","year":"2022"},{"badges":["virtual_appt","home_delivery"],"bodystyle":"SUV","canonical_mmt":"Subaru:Outback:Touring XT","cat":"crossover_midsize","certified_preowned":false,"cpo_indicator":false,"customer_id":"6058393","exterior_color":"Crystal Black Silica","fuel_type":"Gasoline","listing_id":"61395859-7e64-4ecf-b0d6-7fd58f789208","make":"Subaru","mileage":"0","model":"Outback","msrp":"42848","nvi_program":false,"price":"42848","seller_type":"dealership","sponsored":false,"sponsored_type":"none","stock_sub":"","stock_type":"New","trim":"Touring XT","vin":"4S4BTGPD5N3218843","year":"2022"},{"badges":["virtual_appt","home_delivery"],"bodystyle":"SUV","canonical_mmt":"Subaru:Outback:Touring XT","cat":"crossover_midsize","certified_preowned":false,"cpo_indicator":false,"customer_id":"5397709","exterior_color":"Magnetite Gray Metallic","fuel_type":"Gasoline","listing_id":"4a41e9ab-7309-4962-9a56-891b9cc06905","make":"Subaru" ...
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","name":"2022 Subaru Outback Touring XT","position":1,"url":"https://www.cars.com/vehicledetail/37a40c0b-2c7c-4a5b-a532-b0838b31872b//"},{"@type":"ListItem","name":"2022 Subaru Outback Premium","position":2,"url":"https://www.cars.com/vehicledetail/ecf13d20-b900-495e-b42f-e734398f24b5//"},{"@type":"ListItem","name":"2022 Subaru Outback Touring XT","position":3,"url":"https://www.cars.com/vehicledetail/61395859-7e64-4ecf-b0d6-7fd58f789208//"},{"@type":"ListItem","name":"2022 Subaru Outback Touring XT","position":4,"url":"https://www.cars.com/vehicledetail/4a41e9ab-7309-4962-9a56-891b9cc06905//"},{"@type":"ListItem","name":"2022 Subaru Outback Premium","position":5,"url":"https://www.cars.com/vehicledetail/89c1862e-e49f-4c23-963a-f202a7fb8d4f//"},{"@type":"ListItem","name":"2022 Subaru Outback Touring","position":6,"url":"https://www.cars.com/vehicledetail/885ccd23-1706-43c7-a5d6-70b23207e43c//"},{"@type":"ListItem","name":"2022 Subaru Outback Touring XT","position":7,"url":"https://www.cars.com/vehicledetail/49649106-f6b4-4267-987d-6b8c3dc4bf50//"},{"@type":"ListItem","name":"2022 Subaru Outback Premium","position":8,"url":"https://www.cars.com/vehicledetail/1b372a2f-39c7-427c-b4ea-c484f1b3989d//"},{"@type":"ListItem","name":"2022 Subaru Outback Premium","position":9,"url":"https://www.cars.com/vehicledetail/93784ad2-1a0a-4a4d-84b9-bf3aa6feae63//"},{"@type":"ListItem","name":"2022 Subaru Outback Touring XT","position":10,"url":"https://www.cars.com/vehicledetail/66ec33b4-1a3f-4218-8290-82e94a2e7d4c//"},{"@type":"ListItem","name":"2022 Subaru Outback Limited XT","position":11,"url":"https://www.cars.com/vehicledetail/87e52041-6adc-47a6-800f-cee54a93fccb//"},{"@type":"ListItem","name":"2022 Subaru Outback Limited XT","position":12,"url":"https://www.cars.com/vehicledetail/82a62bb8-46ef-441c-a60f-9f2dd53a8c08//"},{"@type":"ListItem","name":"2022 Subaru Outback Limited","position":13,"url":"https://www.cars.com/vehicledetail/aea44366-36b1-4613-8e32-b720f2c01850//"},{"@type":"ListItem","name":"2022 Subaru Outback Onyx Edition XT","position":14,"url":"https://www.cars.com/vehicledetail/58bd9a59-174f-44da-90d4-91b7b13cf7bb//"},{"@type":"ListItem","name":"2022 Subaru Outback Wilderness","position":15,"url":"https://www.cars.com/vehicledetail/c50b76fe-a490-4f7c-aede-785b3ce9e26e//"},{"@type":"ListItem","name":"2022 Subaru Outback Touring XT","position":16,"url":"https://www.cars.com/vehicledetail/a9ccae1e-53bb-4818-a959-087daf130bcc//"},{"@type":"ListItem","name":"2022 Subaru Outback Premium","position":17,"url":"https://www.cars.com/vehicledetail/02bd129c-5018-4032-af4a-b050b1e4b15a//"},{"@type":"ListItem","name":"2022 Subaru Outback Premium","position":18,"url":"https://www.cars.com/vehicledetail/57a6aa72-f07a-4256-be29-25b064d4be3e//"},{"@type":"ListItem","name":"2022 Subaru Outback Touring XT","position":19,"url":"https://www.cars.com/vehicledetail/7c3846d3-07ed-476e-8841-ab4acf5ddf89//"},{"@type":"ListItem","name":"2022 Subaru Outback Limited XT","position":20,"url":"https://www.cars.com/vehicledetail/bcba0da0-3b2f-4a50-ae00-cc0c02692843//"}],"itemListOrder":"https://schema.org/ItemListUnordered","numberOfItems":20}</script>
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Subaru"},"color":"Abyss Blue Pearl","description":"New 2022 Subaru Outback for sale for $42,778.","driveWheelConfiguration":"All-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/24051a28-2efc-5ddf-9e47-860739d4c487/6aaab08c-7cc5-4162-ad68-af02ddf6222f/jFc7dhuai9oSlfsAFsPIvbtyR6k.jpg"},"itemCondition":"https://schema.org/NewCondition","mileageFromOdometer":"1","name":"New 2022 Subaru Outback","sku":"SOLD","vehicleIdentificationNumber":"4S4BTGPD4N3258072","vehicleInteriorColor":"Java Brown","vehicleTransmission":"lineartronic continuously variable"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Subaru"},"color":"Abyss Blue Pearl","description":"New 2022 Subaru Outback for sale for $32,646.","driveWheelConfiguration":"All-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/afb2a7b8-d2ac-5b80-877f-1843c21924d7/fd3be533-8e5f-418c-b192-320c5e3240c9/e5sxxikRchFhPSg_suueX10ncg4.jpg"},"itemCondition":"https://schema.org/NewCondition","mileageFromOdometer":"5","name":"New 2022 Subaru Outback","sku":"S2305","vehicleIdentificationNumber":"4S4BTADC1N3236720","vehicleInteriorColor":"Black","vehicleTransmission":"Automatic CVT"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Subaru"},"color":"Crystal Black Silica","description":"New 2022 Subaru Outback for sale for $42,848.","driveWheelConfiguration":"All-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/fea7c183-cecb-4964-9811-cbbecd985bf0/7c309512-c69b-478f-a66d-bf822215b7ea/O0ktt9x1OsHXUzPeOkmjPfgwqfY.jpg"},"itemCondition":"https://schema.org/NewCondition","mileageFromOdometer":"0","name":"New 2022 Subaru Outback","sku":"220031","vehicleIdentificationNumber":"4S4BTGPD5N3218843","vehicleInteriorColor":"Java Brown","vehicleTransmission":"continuously variable automatic"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Subaru"},"color":"Magnetite Gray Metallic","description":"New 2022 Subaru Outback for sale for $40,357.","driveWheelConfiguration":"AWD","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/color_matched_stock_photos/a06e47e0-cdee-4c28-95da-d394b34d7b55/7f72e741-f535-4792-97e9-282c4b8a63d4.jpg"},"itemCondition":"https://schema.org/NewCondition","mileageFromOdometer":"1","name":"New 2022 Subaru Outback","sku":"TBD156","vehicleIdentificationNumber":"4S4BTGPD1N3TBD156","vehicleInteriorColor":"Java Brown","vehicleTransmission":"Automatic CVT"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Subaru"},"color":"Ice Silver Metallic","description":"New 2022 Subaru Outback for sale for $32,844.","driveWheelConfiguration":"All-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/afb2a7b8-d2ac-5b80-877f-1843c21924d7/6ceed648-7f17-48ee-960f-cd6250acdd58/d1-QP8iY0aketz_qIXiW78s8MNI.jpg"},"itemCondition":"https://schema.org/NewCondition","mileageFromOdometer":"7","name":"New 2022 Subaru Outback","sku":"S2368","vehicleIdentificationNumber":"4S4BTADC2N3255387","vehicleInteriorColor":"Black","vehicleTransmission":"Automatic CVT"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Subaru"},"colo ...
# <nav class="search-filter-bar">
# <button class="subscribe-with-save-status-indicator" data-activity-rule-type="custom" data-component="save-search-add" data-linkname="save-search-sign-up" id="search_filter_bar_save_search_button" phx-click="save_search" phx-target="#search_filter_bar_save_search_button">
# <ep-svg class="save-status-indicator unsaved" name="heart-empty">
# </ep-svg>
# <span>Save search</span>
# </button>
# <button phx-click="show_sort_overlay">
# Sort
#     </button>
# <button id="show-search-form-overlay" phx-click="show_search_form_overlay">
# Filter
#     </button>
# </nav>
# <section class="sds-page-section search-live" id="search-live-container">
# <div class="display-ad" data-ad-sizes="[[970, 90], [728, 90], [970, 250], [320, 50]]" data-ad-type="full-page-width" data-ad-unit-path="6427/shop/new.srp/top" data-appnexus-placement-id="17848526" data-hidden-on="" id="srp-top" phx-update="ignore">
# <div alt="Advertisement" id="phx-ignore-container-srp-top" phx-update="ignore"></div>
# </div>
# </section>
# <header class="sds-page-section__header">
# <nav aria-label="breadcrumb">
# <ul class="sds-breadcrumb sds-breadcrumb--mobile-custom">
# <li class="sds-breadcrumb__parent">
# <span class="sds-icon">
# <svg aria-describedby="description" aria-labelledby="title" fill="none" height="16" role="img" stroke="#000000" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="16" xmlns="http://www.w3.org/2000/svg">
# <title id="title">arrow-left</title>
# <desc id="description">An arrow pointing left.</desc>
# <path d="M19 12H6M12 5l-7 7 7 7"></path></svg>
# </span>
# <span><a data-component="breadcrumb" data-linkname="Home" href="/">Home</a></span>
# </li>
# ...
# <li><a aria-describedby="new-tab-link" aria-label="Dealer Login, External link" class="sds-link--ext" data-activity-rule-type="custom" data-linkname="footer-dealer-login" href="https://dealerdash.cars.com/" rel="noopener" target="_blank">Dealer Login<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# </ul>
# </div>
# </div>
# <div class="accordion-group">
# <div aria-controls="footer-section-3" aria-expanded="false" class="accordion-header" id="footer-header-3" role="button" tabindex="0">
# <span class="global-footer-heading accordion-section-title">Explore Our Brand</span>
# <svg class="accordion-section-icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# <div aria-labelledby="footer-header-3" class="accordion-panel" hidden="" id="footer-section-3" role="region">
# <ul class="global-footer-list sds-list">
# <li><a aria-describedby="new-tab-link" aria-label="Dealer Inspire, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="1" data-linkname="footer-dealer-inspire" href="https://www.dealerinspire.com/" rel="noopener" target="_blank">Dealer Inspire<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="DealerRater, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="2" data-linkname="footer-dealerrater" href="https://www.dealerrater.com/" rel="noopener" target="_blank">DealerRater<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="FUEL, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="3" data-linkname="footer-fuel" href="https://fuel.cars" rel="noopener" target="_blank">FUEL<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Auto.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="4" data-linkname="footer-autocom" href="https://www.auto.com/" rel="noopener" target="_blank">Auto.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="NewCars.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="5" data-linkname="footer-newcarscom" href="https://www.newcars.com/" rel="noopener" target="_blank">NewCars.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Pickuptrucks.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="6" data-linkname="footer-pickuptruckscom" href="https://www.pickuptrucks.com/" rel="noopener" target="_blank">Pickuptrucks.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="global-footer-group accordion-group">
# <div aria-controls="footer-section-4" aria-expanded="false" class="accordion-header" id="footer-header-4" role="button" tabindex="0">
# <span class="global-footer-heading accordion-section-title">Our Company</span>
# <svg class="accordion-section-icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# <div aria-labelledby="footer-header-4" class="accordion-panel" hidden="" id="footer-section-4" role="region">
# <ul class="global-footer-list sds-list">
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="1" data-linkname="footer-about-cars" href="/about/">About Cars.com</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="2" data-linkname="footer-contact-cars" href="/contact/">Contact Cars.com</a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Investor Relations, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="3" data-linkname="footer-investor-relations" href="https://investor.cars.com/overview/default.aspx" rel="noopener" target="_blank">Investor Relations<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="4" data-linkname="footer-careers" href="/careers/">Careers</a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Licensing &amp; Reprints, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="5" data-linkname="footer-licensing-reprints" href="https://info.wrightsmedia.com/cars-licensing-reprints" rel="noopener" target="_blank">Licensing &amp; Reprints<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="6" data-linkname="footer-site-map" href="/sitemap/">Site Map</a></li>
# <li><a data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="7" data-linkname="footer-feedback" data-target="#qualtrics-modal" data-toggle="modal" href="#">Feedback</a></li>
# </ul>
# </div>
# </div>
# <div class="global-footer-group global-footer-apps-and-social">
# <div class="global-footer-social-header">
# <span class="global-footer-heading">Our Mobile App</span>
# </div>
# <div class="global-footer-mobile-apps">
# <a data-activity-rule-type="page-over-page" data-linkname="footer-mobile-apps" href="/mobile/">Download the App Today</a>
# <div class="global-footer-mobile-buttons">
# <a data-activity-rule-type="custom" data-linkname="footer-app-store" href="https://apps.apple.com/us/app/cars-com-new-used-cars/id353263352">
# <img alt="App Store download" class="app-store-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/app-store-badge-us-black-1.png"/>
# </a>
# <a data-activity-rule-type="custom" data-linkname="footer-google-play" href="https://play.google.com/store/apps/details?id=com.cars.android&amp;hl=en_US">
# <img alt="Google Play download" class="google-play-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/google-play-badge-us-1.png"/>
# </a>
# </div>
# </div>
# <div class="global-footer-social-header">
# <span class="global-footer-heading">Connect With Us</span>
# </div>
# <div class="global-footer-social-buttons">
# <ul class="global-footer-list sds-list">
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Twitter, External link" class="sds-link--ext sds-button--icon sds-icon--contain twitter" data-activity-rule-type="custom" data-component="footer-social" data-component-index="1" data-linkname="footer-twitter" href="https://twitter.com/carsdotcom" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#twitter"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Facebook, External link" class="sds-link--ext sds-button--icon sds-icon--contain facebook" data-activity-rule-type="custom" data-component="footer-social" data-component-index="2" data-linkname="footer-facebook" href="https://www.facebook.com/CarsDotCom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#facebook"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Youtube, External link" class="sds-link--ext sds-button--icon sds-icon--contain youtube" data-activity-rule-type="custom" data-component="footer-social" data-component-index="3" data-linkname="footer-youtube" href="https://www.youtube.com/user/Carscom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#youtube"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Instagram, External link" class="sds-link--ext sds-button--icon sds-icon--contain instagram" data-activity-rule-type="custom" data-component="footer-social" data-component-index="4" data-linkname="footer-instagram" href="https://www.instagram.com/carsdotcom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#instagram"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Linkedin, External link" class="sds-link--ext sds-button--icon sds-icon--contain linkedin" data-activity-rule-type="custom" data-component="footer-social" data-component-index="5" data-linkname="footer-linkedin" href="https://www.linkedin.com/company/cars-com" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#linkedin"></use></svg></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="global-copyright">
# <div class="sds-container">
# <ul class="sds-list">
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="1" data-linkname="footer-tos" href="/about/terms/">Terms of Service</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="2" data-linkname="footer-privacy-statement" href="/about/privacy/">Privacy Statement</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="3" data-linkname="footer-personal-information" href="/about/ccpa-privacy-notice/">Do Not Sell My Personal Information</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="4" data-linkname="footer-accessibility" href="/about/accessibility/">Accessibility Statement</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="5" data-linkname="footer-ad-choices" href="/about/ad-choices/">Ad Choices</a></li>
# </ul>
# <div class="global-copyright-copy">©
# 2022 Cars.com. All rights reserved.</div>
# </div>
# </div>
# <div aria-modal="true" class="sds-modal sds-modal-one" id="qualtrics-modal">
# <div class="sds-modal__content">
# <div class="sds-modal__content-head sds-modal__content-head">
# <div class="sds-icon--target btn-close js-close" role="button">
# <span class="sds-icon">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <iframe class="qualtrics-form" data-src="https://cars.qualtrics.com/jfe/form/SV_81Hx3Jkheo8zhmC " height="800px" width="600px"></iframe>
# </div>
# </div>
# </footer>
# <script src=""></script>
# <link data-href="/f7330cd9b0313064f6ae/css/common.css?vsn=d" media="print" rel="stylesheet">
# <link data-href="/f7330cd9b0313064f6ae/css/srp.css?vsn=d" media="print" rel="stylesheet">
# <script>
#   window.CARS = window.CARS || {}
#   window.CARS["initialActivity"] = {"aff_code":"national","cat":null,"customer_id":"","designated_market_area_key":null,"lat_long":"/","local_zone":null,"loginStatus":false,"make":"","market_name":null,"marketing_click_data":null,"marketing_click_id":"","marketing_referral_source":"","model":"","page_channel":"shopping","page_detail":null,"page_key":"search-results","page_name":"shopping/search-results","page_type":"shopping/search-results","platform_id":"cars_responsive","profileAccountType":null,"seller_id":null,"trip_id":"","url_base":"","url_referer":"","useragent":"","utm_campaign":null,"utm_content":null,"utm_medium":null,"utm_source":null,"utm_term":null,"year":"","zip_ip2geo":null}
# </script>
# <script>
#   window.CARS = window.CARS || {}
#   window.CARS["initialAls"] = {"als_private_data":"QTEyOEdDTQ.YYCRH2v1LQYrHA4Mjp9IOjjcD24rFTU1DKGvpZNjFSGRGlp4hgKTHA1NDxA.bx_wQdq7V-osz3KZ.U4QkL0EAue8NP-bSwfz2-zD2XvWEiCRlBz16W4Q7eXgokpiPJqwx70-z7ifoVmrVm2ElBm0.JGqdQldnmTuSB0eWTPd_LQ","page_instance_id":"Fv0zO8qHXd6K4OQBCXEh","page_url":"https://www.cars.com/shopping/results/?stock_type=new&amp;makes[]=subaru&amp;models[]=subaru-outback&amp;list_price_max=&amp;maximum_distance=20&amp;zip=","is_bot":true,"timestamp_utc":1656536570107,"useragent":"python-requests/2.26.0","adobe_id":null,"device_os":null,"utm_source":null,"ga_client_id":null,"stock_type":"","results_page_number":1,"utm_campaign":null,"utm_term":null,"aff_code":"national","utm_content":null,"trim":"","x_forwarded_for":null,"cpo_indicator":false,"marketing_click_id":"","lead_event_id":null,"model_year":"","model":"","device_model":null,"marketing_click_source":"","app_version":null,"pdid":null,"platform_id":"cars_responsive","incentive_ids":"","bodystyle":"","seller_id":null,"upsells":[],"web_page_type_to":"shopping/search-results","price":null,"referer_url":"","listing_id":"","trip_id":"","utm_medium":null,"internet_connection":null,"web_page_type_from":"","device_id":null,"search_zipcode":"","bot_type":"Unknown Bot (python-reque_B0B1CB20BEBCAE0F191F2D67CC6B7C5E):monitor:Behavior Anomaly;HTTP Libraries:100:aggressive","device_type":"desktop","longitude":null,"horizontal_position":"","latitude":null,"search_instance_id":null,"customer_id":"","total_results":3026,"profile_user_id":null,"vertical_position":"","msrp":"","roxanne_visit_id":"","results_page_count":152,"results_per_page":20,"carrier":null,"make":"","igo_zipcode":"","roxanne_visitor_id":"","experiment_ids":"[{&quot;index&quot;:0,&quot;name&quot;:&quot;ab_test_2_srp_hp_prod&quot;}]"}
# </script>
# <script async="" data-src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   window.pbjs = window.pbjs || {que: []};
#   window.CARS = window.CARS || {};
#   window.CARS.disableAds = false;
#   window.CARS.disablePrebid = true;
#   window.CARS.isTest = false
# </script>
# <script async="" data-src="https://assets.adobedtm.com/306a737f2df1/a3d882c1ebd5/launch-3edaffcf6794.min.js"></script>
# <script async="" data-src="https://d1n00d49gkbray.cloudfront.net/js/cars.js"></script>
# <script async="" data-src="https://accounts.google.com/gsi/client" defer=""></script>
# <script>
#   window.CARS["dispatcher"] = [];
#   window.CARS["dispatcher"].push({"CarsWeb": null})
#
#
# </script>
# <script id="graphql-config" type="application/json">
#     {
#
#       "apiKey": "5rrmnWVl1MDzPcEnDvEp3Pu101IGXEGo",
#       "url": "https://graph.cars.com/graphql/api"
#     }
#   </script>
# <script src="/Jr_o5A0q9-yp/UMXga4mDG-/O6/7fzEXbpzXa9N/UC1IAQ/ZkQUSH/NETx4" type="text/javascript"></script></link></link></body>
# </html>

# %%
results = soup.find_all('div', class_ ="vehicle-card")

# %%
print(results)
# Out:
# [<div class="vehicle-card" data-listing-id="37a40c0b-2c7c-4a5b-a532-b0838b31872b" data-override-payload='{"sponsored_type":"none","vertical_position":1}' data-tracking-id="1" data-tracking-type="srp-vehicle-card" id="vehicle-card-37a40c0b-2c7c-4a5b-a532-b0838b31872b" phx-hook="VehicleCard" phx-target="6">
# <a class="vehicle-card-visited-tracking-link" href="/vehicledetail/37a40c0b-2c7c-4a5b-a532-b0838b31872b/" rel="nofollow" tabindex="-1"></a>
# <div class="vehicle-card-main js-gallery-click-card">
# <div class="vehicle-card-photos js-gallery-click-gallery">
# <div class="gallery-wrap">
# <div aria-label="Photo 1 of 1 of 2022 Subaru Outback Touring XT" class="image-wrap" data-index="0">
# <img alt="Photo 1 of 1 of 2022 Subaru Outback Touring XT" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/24051a28-2efc-5ddf-9e47-860739d4c487/6aaab08c-7cc5-4162-ad68-af02ddf6222f/jFc7dhuai9oSlfsAFsPIvbtyR6k.jpg"/>
# </div>
# </div>
# <div class="gallery-indicator"><span class="gallery-indicator-current-image">1</span>/1</div>
# </div>
# <div class="vehicle-details">
# <div class="save-vehicle">
# <div class="favorite">
# <button class="heart" data-activity-rule-type="custom" data-component="save-vehicle-add" data-hook-heart-id="vehicle-heart-1" data-index="1" data-linkname="save-vehicle-sign-up" data-listing-id="37a40c0b-2c7c-4a5b-a532-b0838b31872b" id="vehicle-heart-1" onclick="event.preventDefault()" phx-click="save_listing" phx-hook="RecordSaveListingAction" phx-target="84" phx-value-is_vdp="false" phx-value-listing_id="37a40c0b-2c7c-4a5b-a532-b0838b31872b">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#heart"></use></svg>
# <span class="text">Save</span>
# </button>
# </div>
# </div>
# <p class="stock-type">New</p>
# <a class="vehicle-card-link js-gallery-click-link" data-activity-rule-type="page-over-page" data-linkname="vehicle-listing" href="/vehicledetail/37a40c0b-2c7c-4a5b-a532-b0838b31872b/" rel="nofollow" target="">
# <h2 class="title">2022 Subaru Outback Touring XT</h2>
# </a>
# <div class="price-section price-section-vehicle-card">
# <span class="primary-price">$42,778</span>
# </div>
# <span class="estimated-monthly-payments-tooltip js-tooltip-container">
# <div class="list-item-tooltip-container" data-hook-annual-percentage-rate="5.99" data-hook-base-price="42778" data-hook-down-payment-percentage="0.2" data-hook-index="1" data-hook-length-of-loan="72" data-hook-link-name="srp-mo-payment-tooltip-toggle" id="emp-tooltip-1" phx-hook="MonthlyPaymentsCalculator">
# <span class="sds-tooltip">
# <a class="sds-link" data-override-payload='{"bodystyle":"suv","cpo_indicator":false,"customer_id":"5343485","listing_id":"37a40c0b-2c7c-4a5b-a532-b0838b31872b","make":"subaru","model":"outback","model_year":"2022","msrp":"42778","price":42778,"results_page_number":1,"sponsored?":false,"sponsored_type":"none","stock_type":"new","trim":"touring_xt","vertical_position":1}' tabindex="0">
# <span class="js-estimated-monthly-payment-formatted-value-with-abr"></span> <svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#info"></use></svg>
# </a>
# </span>
# <div class="sds-tooltip__window js-tooltip-content" data-reveal-method="inline" id="tooltip-est-monthly-payment-1" role="tooltip">
# <p>
# Estimated monthly payment of  <span class="js-estimated-monthly-payment-formatted-value"></span>.
# Based on a vehicle price of $42,778, on a 72 month loan with 5.99% APR and a 20.00% down payment.
#       </p>
# <div class="sds-icon sds-icon--contain custom-close-tooltip" data-target="tooltip-est-monthly-payment-1">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#close"></use></svg>
# </div>
# </div>
# </div>
# </span>
# <div class="vehicle-badging" data-click-intent-id="badges-explainer" data-contents='{"home_delivery_badge":true,"virtual_appointments_badge":true,"href_to_vdp":{"href_to_vdp":"/vehicledetail/37a40c0b-2c7c-4a5b-a532-b0838b31872b/?bodystyle=suv&amp;cpo_indicator=false&amp;customer_id=5343485&amp;intent_id=badges-explainer&amp;listing_id=37a40c0b-2c7c-4a5b-a532-b0838b31872b&amp;make=subaru&amp;model=outback&amp;model_year=2022&amp;msrp=42778&amp;price=42778&amp;sponsored%3F=false&amp;stock_type=new&amp;trim=touring+xt"}}' data-override-payload='{"bodystyle":"suv","cpo_indicator":false,"customer_id":"5343485","horizontal_position":null,"listing_id":"37a40c0b-2c7c-4a5b-a532-b0838b31872b","make":"subaru","model":"outback","model_year":"2022","msrp":"42778","price":"42778","results_page_number":1,"sponsored?":false,"stock_type":"new","trim":"touring xt","vertical_position":1,"web_page_type_from":"shopping/search-results"}' data-target="#sds-modal" data-toggle="expanda-modal" tabindex="0">
# <div class="sds-badge sds-badge--home-delivery">
# <span class="sds-badge__label">Home Delivery</span>
# </div>
# <div class="sds-badge sds-badge--virtual-appointments">
# <span class="sds-badge__label">Virtual Appointments</span>
# </div>
# </div>
# <div class="vehicle-links external-links">
# </div>
# <div class="vehicle-dealer">
# <div class="dealer-name">
# <strong>Patriot Subaru of NA</strong>
# </div>
# <div class="sds-rating">
# <span class="sds-rating__count">4.9</span>
# <div class="sds-rating__wrapper">
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# </div>
# <span class="sds-rating__link sds-button-link">(83 reviews)</span>
# </div>
# <div class="miles-from hidden" data-qa="miles-from-user">
#        mi. from
#     </div>
# </div>
# </div>
# <div class="contact-buttons" id="37a40c0b-2c7c-4a5b-a532-b0838b31872b-lead-btns">
# <a class="sds-button--secondary contact-by-phone" data-activity-rule-type="custom" data-call-intent-id="srp-call-intent" data-index="1" data-linkname="dealer-phone-srp" data-listing-id="37a40c0b-2c7c-4a5b-a532-b0838b31872b" data-make="Subaru" data-model="Outback" data-phone-number="7742249468" data-trim="Touring XT" data-vin="4S4BTGPD4N3258072" data-year="2022" href="tel:+1-774-224-9468" id="dealer-phone-37a40c0b-2c7c-4a5b-a532-b0838b31872b" phx-hook="CallSourceDniSRPCallButton" phx-update="ignore">Call</a>
# <button class="sds-button lead-form-modal-button" data-activity-rule-type="custom" data-click-intent-id="open-lead-form-modal" data-dealer-customer-id="5343485" data-index="1" data-linkname="email-lead-form-srp" data-listing-id="37a40c0b-2c7c-4a5b-a532-b0838b31872b" data-override-payload='{"bodystyle":"SUV","customer_id":"5343485","listing_id":"37a40c0b-2c7c-4a5b-a532-b0838b31872b","make":"Subaru","model":"Outback","model_year":"2022","msrp":"42778","price":"42778","stock_type":"New","vertical_position":1}' data-sponsored="false" data-sponsored-invariant="false" data-sponsored-type="none" id="lead-form-email-37a40c0b-2c7c-4a5b-a532-b0838b31872b" phx-hook="ShowLeadForm">Check availability</button>
# <button class="sds-button lead-form-modal-button--desktop srp" data-activity-rule-type="custom" data-click-intent-id="open-lead-form-modal" data-dealer-customer-id="5343485" data-index="1" data-linkname="email-lead-form-srp" data-listing-id="37a40c0b-2c7c-4a5b-a532-b0838b31872b" data-override-payload='{"bodystyle":"SUV","customer_id":"5343485","listing_id":"37a40c0b-2c7c-4a5b-a532-b0838b31872b","make":"Subaru","model":"Outback","model_year":"2022","msrp":"42778","price":"42778","stock_type":"New","vertical_position":1}' data-sponsored="false" data-sponsored-invariant="false" data-sponsored-type="none" id="lead-form-37a40c0b-2c7c-4a5b-a532-b0838b31872b" phx-hook="ShowLeadForm">Check availability</button>
# </div>
# </div>
# </div>, <div class="vehicle-card" data-listing-id="ecf13d20-b900-495e-b42f-e734398f24b5" data-override-payload='{"sponsored_type":"none","vertical_position":2}' data-tracking-id="2" data-tracking-type="srp-vehicle-card" id="vehicle-card-ecf13d20-b900-495e-b42f-e734398f24b5" phx-hook="VehicleCard" phx-target="7">
# <a class="vehicle-card-visited-tracking-link" href="/vehicledetail/ecf13d20-b900-495e-b42f-e734398f24b5/" rel="nofollow" tabindex="-1"></a>
# <div class="vehicle-card-main js-gallery-click-card">
# <div class="vehicle-card-photos js-gallery-click-gallery">
# <div class="gallery-wrap">
# <div aria-label="Photo 1 of 12 of 2022 Subaru Outback Premium" class="image-wrap" data-index="0">
# <img alt="Photo 1 of 12 of 2022 Subaru Outback Premium" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/afb2a7b8-d2ac-5b80-877f-1843c21924d7/fd3be533-8e5f-418c-b192-320c5e3240c9/e5sxxikRchFhPSg_suueX10ncg4.jpg"/>
# </div>
# <div aria-label="Photo 2 of 12 of 2022 Subaru Outback Premium" class="image-wrap" data-index="1">
# <img alt="Photo 2 of 12 of 2022 Subaru Outback Premium" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/afb2a7b8-d2ac-5b80-877f-1843c21924d7/fd3be533-8e5f-418c-b192-320c5e3240c9/30x_U3o5zQIglHXnPSSu-u2y9O4.jpg"/>
# </div>
# <div aria-label="Photo 3 of 12 of 2022 Subaru Outback Premium" class="image-wrap" data-index="2">
# <img alt="Photo 3 of 12 of 2022 Subaru Outback Premium" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/afb2a7b8-d2ac-5b80-877f-1843c21924d7/fd3be533-8e5f-418c-b192-320c5e3240c9/-D5J_1YdiZWk_Y5j_MJPvjw-mko.jpg"/>
# </div>
# <div aria-label="Photo 4 of 12 of 2022 Subaru Outback Premium" class="image-wrap" data-index="3">
# <img alt="Photo 4 of 12 of 2022 Subaru Outback Premium" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/afb2a7b8-d2ac-5b80-877f-1843c21924d7/fd3be533-8e5f-418c-b192-320c5e3240c9/PtwBFdD-tm3KVVmxuCNuWtlghJY.jpg"/>
# </div>
# <div aria-label="Photo 5 of 12 of 2022 Subaru Outback Premium" class="image-wrap" data-index="4">
# <img alt="Photo 5 of 12 of 2022 Subaru Outback Premium" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/afb2a7b8-d2ac-5b80-877f-1843c21924d7/fd3be533-8e5f-418c-b192-320c5e3240c9/3P1d93cnKBpn4UOSVcodSTNa6T0.jpg"/>
# </div>
# <div aria-label="Photo 6 of 12 of 2022 Subaru Outback Premium" class="image-wrap" data-index="5">
# <div class="gallery-view-all">
# <img alt="" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/afb2a7b8-d2ac-5b80-877f-1843c21924d7/fd3be533-8e5f-418c-b192-320c5e3240c9/CgigdSpS0TIaTTPu8wdomyOYDek.jpg" src="/images/placeholder_10x10.png"/>
# <div class="sds-button sds-button--secondary-dense">View all 12 photos</div>
# </div>
# </div>
# </div>
# <button class="image-control-left">
# <div class="rectangle rectangle-left">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </button>
# <button class="image-control-right">
# <div class="rectangle rectangle-right">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </button>
# <div class="gallery-indicator"><span class="gallery-indicator-current-image">1</span>/12</div>
# <div class="gallery-nav">
# <div class="image-indicator selected"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# </div>
# </div>
# <div class="vehicle-details">
# <div class="save-vehicle">
# <div class="favorite">
# <button class="heart" data-activity-rule-type="custom" data-component="save-vehicle-add" data-hook-heart-id="vehicle-heart-2" data-index="2" data-linkname="save-vehicle-sign-up" data-listing-id="ecf13d20-b900-495e-b42f-e734398f24b5" id="vehicle-heart-2" onclick="event.preventDefault()" phx-click="save_listing" phx-hook="RecordSaveListingAction" phx-target="85" phx-value-is_vdp="false" phx-value-listing_id="ecf13d20-b900-495e-b42f-e734398f24b5">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#heart"></use></svg>
# <span class="text">Save</span>
# </button>
# </div>
# </div>
# <p class="stock-type">New</p>
# <a class="vehicle-card-link js-gallery-click-link" data-activity-rule-type="page-over-page" data-linkname="vehicle-listing" href="/vehicledetail/ecf13d20-b900-495e-b42f-e734398f24b5/" rel="nofollow" target="">
# <h2 class="title">2022 Subaru Outback Premium</h2>
# </a>
# <div class="price-section price-section-vehicle-card">
# <span class="primary-price">$32,646</span>
# </div>
# <span class="estimated-monthly-payments-tooltip js-tooltip-container">
# <div class="list-item-tooltip-container" data-hook-annual-percentage-rate="5.99" data-hook-base-price="32646" data-hook-down-payment-percentage="0.2" data-hook-index="2" data-hook-length-of-loan="72" data-hook-link-name="srp-mo-payment-tooltip-toggle" id="emp-tooltip-2" phx-hook="MonthlyPaymentsCalculator">
# <span class="sds-tooltip">
# <a class="sds-link" data-override-payload='{"bodystyle":"suv","cpo_indicator":false,"customer_id":"3538","listing_id":"ecf13d20-b900-495e-b42f-e734398f24b5","make":"subaru","model":"outback","model_year":"2022","msrp":null,"price":32646,"results_page_number":1,"sponsored?":false,"sponsored_type":"none","stock_type":"new","trim":
xt"}}' data-override-payload='{"bodystyle":"suv","cpo_indicator":false,"customer_id":"5397709","horizontal_position":null,"listing_id":"4a41e9ab-7309-4962-9a56-891b9cc06905","make":"subaru","model":"outback","model_year":"2022","msrp":"40357","price":"40357","results_page_number":1,"sponsored?":false,"stock_type":"new","trim":"touring xt","vertical_position":4,"web_page_type_from":"shopping/search-results"}' data-target="#sds-modal" data-toggle="expanda-modal" tabindex="0">
# <div class="sds-badge sds-badge--home-delivery">
# <span class="sds-badge__label">Home Delivery</span>
# </div>
# <div class="sds-badge sds-badge--virtual-appointments">
# <span class="sds-badge__label">Virtual Appointments</span>
# </div>
# </div>
# <div class="vehicle-links external-links">
# </div>
# <div class="vehicle-dealer">
# <div class="dealer-name">
# <strong>Blaise Alexander Subaru of Lewistown</strong>
# </div>
# <div class="sds-rating sds-rating--empty">
# <div class="sds-rating__wrapper">
# <span class="sds-rating__item">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# </div>
# <span class="sds-rating__link sds-button-link">(0 reviews)</span>
# </div>
# <div class="miles-from hidden" data-qa="miles-from-user">
#        mi. from
#     </div>
# </div>
# </div>
# <div class="contact-buttons" id="4a41e9ab-7309-4962-9a56-891b9cc06905-lead-btns">
# <a class="sds-button--secondary contact-by-phone" data-activity-rule-type="custom" data-call-intent-id="srp-call-intent" data-index="4" data-linkname="dealer-phone-srp" data-listing-id="4a41e9ab-7309-4962-9a56-891b9cc06905" data-make="Subaru" data-model="Outback" data-phone-number="7173638610" data-trim="Touring XT" data-vin="4S4BTGPD1N3TBD156" data-year="2022" href="tel:+1-717-363-8610" id="dealer-phone-4a41e9ab-7309-4962-9a56-891b9cc06905" phx-hook="CallSourceDniSRPCallButton" phx-update="ignore">Call</a>
# <button class="sds-button lead-form-modal-button" data-activity-rule-type="custom" data-click-intent-id="open-lead-form-modal" data-dealer-customer-id="5397709" data-index="4" data-linkname="email-lead-form-srp" data-listing-id="4a41e9ab-7309-4962-9a56-891b9cc06905" data-override-payload='{"bodystyle":"SUV","customer_id":"5397709","listing_id":"4a41e9ab-7309-4962-9a56-891b9cc06905","make":"Subaru","model":"Outback","model_year":"2022","msrp":"40357","price":"40357","stock_type":"New","vertical_position":4}' data-sponsored="false" data-sponsored-invariant="false" data-sponsored-type="none" id="lead-form-email-4a41e9ab-7309-4962-9a56-891b9cc06905" phx-hook="ShowLeadForm">Check availability</button>
# <button class="sds-button lead-form-modal-button--desktop srp" data-activity-rule-type="custom" data-click-intent-id="open-lead-form-modal" data-dealer-customer-id="5397709" data-index="4" data-linkname="email-lead-form-srp" data-listing-id="4a41e9ab-7309-4962-9a56-891b9cc06905" data-override-payload='{"bodystyle":"SUV","customer_id":"5397709","listing_id":"4a41e9ab-7309-4962-9a56-891b9cc06905","make":"Subaru","model":"Outback","model_year":"2022","msrp":"40357","price":"40357","stock_type":"New","vertical_position":4}' data-sponsored="false" data-sponsored-invariant="false" data-sponsored-type="none" id="lead-form-4a41e9ab-7309-4962-9a56-891b9cc06905" phx-hook="ShowLeadForm">Check availability</button>
# </div>
# </div>
# </div>, <div class="vehicle-card" data-listing-id="89c1862e-e49f-4c23-963a-f202a7fb8d4f" data-override-payload='{"sponsored_type":"none","vertical_position":5}' data-tracking-id="5" data-tracking-type="srp-vehicle-card" id="vehicle-card-89c1862e-e49f-4c23-963a-f202a7fb8d4f" phx-hook="VehicleCard" phx-target="10">
# <a class="vehicle-card-visited-tracking-link" href="/vehicledetail/89c1862e-e49f-4c23-963a-f202a7fb8d4f/" rel="nofollow" tabindex="-1"></a>
# <div class="vehicle-card-main js-gallery-click-card">
# <div class="vehicle-card-photos js-gallery-click-gallery">
# <div class="gallery-wrap">
# <div aria-label="Photo 1 of 11 of 2022 Subaru Outback Premium" class="image-wrap" data-index="0">
# <img alt="Photo 1 of 11 of 2022 Subaru Outback Premium" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/afb2a7b8-d2ac-5b80-877f-1843c21924d7/6ceed648-7f17-48ee-960f-cd6250acdd58/d1-QP8iY0aketz_qIXiW78s8MNI.jpg" src="/images/placeholder_10x10.png"/>
# </div>
# <div aria-label="Photo 2 of 11 of 2022 Subaru Outback Premium" class="image-wrap" data-index="1">
# <img alt="Photo 2 of 11 of 2022 Subaru Outback Premium" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/afb2a7b8-d2ac-5b80-877f-1843c21924d7/6ceed648-7f17-48ee-960f-cd6250acdd58/df4QDqrvyDVNhs8HM35Cjqua6NY.jpg" src="/images/placeholder_10x10.png"/>
# </div>
# <div aria-label="Photo 3 of 11 of 2022 Subaru Outback Premium" class="image-wrap" data-index="2">
# <img alt="Photo 3 of 11 of 2022 Subaru Outback Premium" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/afb2a7b8-d2ac-5b80-877f-1843c21924d7/6ceed648-7f17-48ee-960f-cd6250acdd58/j50MnVwaNYD3Gnb2jGFjoqKRpVY.jpg" src="/images/placeholder_10x10.png"/>
# </div>
# <div aria-label="Photo 4 of 11 of 2022 Subaru Outback Premium" class="image-wrap" data-index="3">
# <img alt="Photo 4 of 11 of 2022 Subaru Outback Premium" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/afb2a7b8-d2ac-5b80-877f-1843c21924d7/6ceed648-7f17-48ee-960f-cd6250acdd58/PtwBFdD-tm3KVVmxuCNuWtlghJY.jpg" src="/images/placeholder_10x10.png"/>
# </div>
# <div aria-label="Photo 5 of 11 of 2022 Subaru Outback Premium" class="image-wrap" data-index="4">
# <img alt="Photo 5 of 11 of 2022 Subaru Outback Premium" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/afb2a7b8-d2ac-5b80-877f-1843c21924d7/6ceed648-7f17-48ee-960f-cd6250acdd58/3P1d93cnKBpn4UOSVcodSTNa6T0.jpg" src="/images/placeholder_10x10.png"/>
# </div>
# <div aria-label="Photo 6 of 11 of 2022 Subaru Outback Premium" class="image-wrap" data-index="5">
# <div class="gallery-view-all">
# <img alt="" class="vehicle-image js-lazy-load styles-lazy-load" data-src="https://platform.cstatic-images.com/large/in/v2/afb2a7b8-d2ac-5b80-877f-1843c21924d7/6ceed648-7f17-48ee-960f-cd6250acdd58/CgigdSpS0TIaTTPu8wdomyOYDek.jpg" src="/images/placeholder_10x10.png"/>
# <div class="sds-button sds-button--secondary-dense">View all 11 photos</div>
# </div>
# </div>
# </div>
# <button class="image-control-left">
# <div class="rectangle rectangle-left">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </button>
# <button class="image-control-right">
# <div class="rectangle rectangle-right">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </button>
# <div class="gallery-indicator"><span class="gallery-indicator-current-image">1</span>/11</div>
# <div class="gallery-nav">
# <div class="image-indicator selected"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# <div class="image-indicator"></div>
# </div>
# </div>
# <div class="vehicle-details">
# <div class="save-vehicle">
# <div class="favorite">
# <button class="heart" data-activity-rule-type="custom" data-component="save-vehicle-add" data-hook-heart-id="vehicle-heart-5" data-index="5" data-linkname="save-vehicle-sign-up" data-listing-id="89c1862e-e49f-4c23-963a-f202a7fb8d4f" id="vehicle-heart-5" onclick="event.preventDefault()" phx-click="save_listing" phx-hook="RecordSaveListingAction" phx-target="88" phx-value-is_vdp="false" phx-value-listing_id="89c1862e-e49f-4c23-963a-f202a7fb8d4f">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#heart"></use></svg>
# <span class="text">Save</span>
# </button>
# </div>
# </div>
# <p class="stock-type">New</p>
# <a class="vehicle-card-link js-gallery-click-link" data-activity-rule-type="page-over-page" data-linkname="vehicle-listing" href="/vehicledetail/89c1862e-e49f-4c23-963a-f202a7fb8d4f/" rel="nofollow" target="">
# <h2 class="title">2022 Subaru Outback Premium</h2>
# </a>
# <div class="price-section price-section-vehicle-card">
# <span class="primary-price">$32,844</span>
# </div>
# <span class="estimated-monthly-payments-tooltip js-tooltip-container">
# <div class="list-item-tooltip-container" data-hook-annual-percentage-rate="5.99" data-hook-base-price="32844" data-hook-down-payment-percentage="0.2" data-hook-index="5" data-hook-length-of-loan="72" data-hook-link-name="srp-mo-payment-tooltip-toggle" id="emp-tooltip-5" phx-hook="MonthlyPaymentsCalculator">
# <span class="sds-tooltip">
# <a class="sds-link" data-override-payload='{"bodystyle":"suv","cpo_indicator":false,"customer_id":"3538","listing_id":"89c1862e-e49f-4c23-963a-f202a7fb8d4f","make":"subaru","model":"outback","model_year":"2022","msrp":null,"price":32844,"results_page_number":1,"sponsored?":false,"sponsored_type":"none","stock_type":"new","trim":

# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#heart"></use></svg>
# <span class="text">Save</span>
# </button>
# </div>
# </div>
# <p class="stock-type">New</p>
# <a class="vehicle-card-link js-gallery-click-link" data-activity-rule-type="page-over-page" data-linkname="vehicle-listing" href="/vehicledetail/bcba0da0-3b2f-4a50-ae00-cc0c02692843/" rel="nofollow" target="">
# <h2 class="title">2022 Subaru Outback Limited XT</h2>
# </a>
# <div class="price-section price-section-vehicle-card">
# <span class="primary-price">$40,898</span>
# </div>
# <span class="estimated-monthly-payments-tooltip js-tooltip-container">
# <div class="list-item-tooltip-container" data-hook-annual-percentage-rate="5.99" data-hook-base-price="40898" data-hook-down-payment-percentage="0.2" data-hook-index="20" data-hook-length-of-loan="72" data-hook-link-name="srp-mo-payment-tooltip-toggle" id="emp-tooltip-20" phx-hook="MonthlyPaymentsCalculator">
# <span class="sds-tooltip">
# <a class="sds-link" data-override-payload='{"bodystyle":"suv","cpo_indicator":false,"customer_id":"6058393","listing_id":"bcba0da0-3b2f-4a50-ae00-cc0c02692843","make":"subaru","model":"outback","model_year":"2022","msrp":"40898","price":40898,"results_page_number":1,"sponsored?":false,"sponsored_type":"none","stock_type":"new","trim":"limited_xt","vertical_position":20}' tabindex="0">
# <span class="js-estimated-monthly-payment-formatted-value-with-abr"></span> <svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#info"></use></svg>
# </a>
# </span>
# <div class="sds-tooltip__window js-tooltip-content" data-reveal-method="inline" id="tooltip-est-monthly-payment-20" role="tooltip">
# <p>
# Estimated monthly payment of  <span class="js-estimated-monthly-payment-formatted-value"></span>.
# Based on a vehicle price of $40,898, on a 72 month loan with 5.99% APR and a 20.00% down payment.
#       </p>
# <div class="sds-icon sds-icon--contain custom-close-tooltip" data-target="tooltip-est-monthly-payment-20">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#close"></use></svg>
# </div>
# </div>
# </div>
# </span>
# <div class="vehicle-badging" data-click-intent-id="badges-explainer" data-contents='{"home_delivery_badge":true,"virtual_appointments_badge":true,"href_to_vdp":{"href_to_vdp":"/vehicledetail/bcba0da0-3b2f-4a50-ae00-cc0c02692843/?bodystyle=suv&amp;cpo_indicator=false&amp;customer_id=6058393&amp;intent_id=badges-explainer&amp;listing_id=bcba0da0-3b2f-4a50-ae00-cc0c02692843&amp;make=subaru&amp;model=outback&amp;model_year=2022&amp;msrp=40898&amp;price=40898&amp;sponsored%3F=false&amp;stock_type=new&amp;trim=limited+xt"}}' data-override-payload='{"bodystyle":"suv","cpo_indicator":false,"customer_id":"6058393","horizontal_position":null,"listing_id":"bcba0da0-3b2f-4a50-ae00-cc0c02692843","make":"subaru","model":"outback","model_year":"2022","msrp":"40898","price":"40898","results_page_number":1,"sponsored?":false,"stock_type":"new","trim":"limited xt","vertical_position":20,"web_page_type_from":"shopping/search-results"}' data-target="#sds-modal" data-toggle="expanda-modal" tabindex="0">
# <div class="sds-badge sds-badge--home-delivery">
# <span class="sds-badge__label">Home Delivery</span>
# </div>
# <div class="sds-badge sds-badge--virtual-appointments">
# <span class="sds-badge__label">Virtual Appointments</span>
# </div>
# </div>
# <div class="vehicle-links external-links">
# </div>
# <div class="vehicle-dealer">
# <div class="dealer-name">
# <strong>One Subaru of Hayward</strong>
# </div>
# <div class="miles-from hidden" data-qa="miles-from-user">
#        mi. from
#     </div>
# </div>
# </div>
# <div class="contact-buttons" id="bcba0da0-3b2f-4a50-ae00-cc0c02692843-lead-btns">
# <a class="sds-button--secondary contact-by-phone" data-activity-rule-type="custom" data-call-intent-id="srp-call-intent" data-index="20" data-linkname="dealer-phone-srp" data-listing-id="bcba0da0-3b2f-4a50-ae00-cc0c02692843" data-make="Subaru" data-model="Outback" data-phone-number="8884610160" data-trim="Limited XT" data-vin="4S4BTGND3N3221453" data-year="2022" href="tel:+1-888-461-0160" id="dealer-phone-bcba0da0-3b2f-4a50-ae00-cc0c02692843" phx-hook="CallSourceDniSRPCallButton" phx-update="ignore">Call</a>
# <button class="sds-button lead-form-modal-button" data-activity-rule-type="custom" data-click-intent-id="open-lead-form-modal" data-dealer-customer-id="6058393" data-index="20" data-linkname="email-lead-form-srp" data-listing-id="bcba0da0-3b2f-4a50-ae00-cc0c02692843" data-override-payload='{"bodystyle":"SUV","customer_id":"6058393","listing_id":"bcba0da0-3b2f-4a50-ae00-cc0c02692843","make":"Subaru","model":"Outback","model_year":"2022","msrp":"40898","price":"40898","stock_type":"New","vertical_position":20}' data-sponsored="false" data-sponsored-invariant="false" data-sponsored-type="none" id="lead-form-email-bcba0da0-3b2f-4a50-ae00-cc0c02692843" phx-hook="ShowLeadForm">Check availability</button>
# <button class="sds-button lead-form-modal-button--desktop srp" data-activity-rule-type="custom" data-click-intent-id="open-lead-form-modal" data-dealer-customer-id="6058393" data-index="20" data-linkname="email-lead-form-srp" data-listing-id="bcba0da0-3b2f-4a50-ae00-cc0c02692843" data-override-payload='{"bodystyle":"SUV","customer_id":"6058393","listing_id":"bcba0da0-3b2f-4a50-ae00-cc0c02692843","make":"Subaru","model":"Outback","model_year":"2022","msrp":"40898","price":"40898","stock_type":"New","vertical_position":20}' data-sponsored="false" data-sponsored-invariant="false" data-sponsored-type="none" id="lead-form-bcba0da0-3b2f-4a50-ae00-cc0c02692843" phx-hook="ShowLeadForm">Check availability</button>
# </div>
# </div>
# </div>]

# %%
len(results)
# Out:
# 20

# %%
results[0]
# Out:
# <div class="vehicle-card" data-listing-id="37a40c0b-2c7c-4a5b-a532-b0838b31872b" data-override-payload='{"sponsored_type":"none","vertical_position":1}' data-tracking-id="1" data-tracking-type="srp-vehicle-card" id="vehicle-card-37a40c0b-2c7c-4a5b-a532-b0838b31872b" phx-hook="VehicleCard" phx-target="6">
# <a class="vehicle-card-visited-tracking-link" href="/vehicledetail/37a40c0b-2c7c-4a5b-a532-b0838b31872b/" rel="nofollow" tabindex="-1"></a>
# <div class="vehicle-card-main js-gallery-click-card">
# <div class="vehicle-card-photos js-gallery-click-gallery">
# <div class="gallery-wrap">
# <div aria-label="Photo 1 of 1 of 2022 Subaru Outback Touring XT" class="image-wrap" data-index="0">
# <img alt="Photo 1 of 1 of 2022 Subaru Outback Touring XT" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/24051a28-2efc-5ddf-9e47-860739d4c487/6aaab08c-7cc5-4162-ad68-af02ddf6222f/jFc7dhuai9oSlfsAFsPIvbtyR6k.jpg"/>
# </div>
# </div>
# <div class="gallery-indicator"><span class="gallery-indicator-current-image">1</span>/1</div>
# </div>
# <div class="vehicle-details">
# <div class="save-vehicle">
# <div class="favorite">
# <button class="heart" data-activity-rule-type="custom" data-component="save-vehicle-add" data-hook-heart-id="vehicle-heart-1" data-index="1" data-linkname="save-vehicle-sign-up" data-listing-id="37a40c0b-2c7c-4a5b-a532-b0838b31872b" id="vehicle-heart-1" onclick="event.preventDefault()" phx-click="save_listing" phx-hook="RecordSaveListingAction" phx-target="84" phx-value-is_vdp="false" phx-value-listing_id="37a40c0b-2c7c-4a5b-a532-b0838b31872b">
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#heart"></use></svg>
# <span class="text">Save</span>
# </button>
# </div>
# </div>
# <p class="stock-type">New</p>
# <a class="vehicle-card-link js-gallery-click-link" data-activity-rule-type="page-over-page" data-linkname="vehicle-listing" href="/vehicledetail/37a40c0b-2c7c-4a5b-a532-b0838b31872b/" rel="nofollow" target="">
# <h2 class="title">2022 Subaru Outback Touring XT</h2>
# </a>
# <div class="price-section price-section-vehicle-card">
# <span class="primary-price">$42,778</span>
# </div>
# <span class="estimated-monthly-payments-tooltip js-tooltip-container">
# <div class="list-item-tooltip-container" data-hook-annual-percentage-rate="5.99" data-hook-base-price="42778" data-hook-down-payment-percentage="0.2" data-hook-index="1" data-hook-length-of-loan="72" data-hook-link-name="srp-mo-payment-tooltip-toggle" id="emp-tooltip-1" phx-hook="MonthlyPaymentsCalculator">
# <span class="sds-tooltip">
# <a class="sds-link" data-override-payload='{"bodystyle":"suv","cpo_indicator":false,"customer_id":"5343485","listing_id":"37a40c0b-2c7c-4a5b-a532-b0838b31872b","make":"subaru","model":"outback","model_year":"2022","msrp":"42778","price":42778,"results_page_number":1,"sponsored?":false,"sponsored_type":"none","stock_type":"new","trim":"touring_xt","vertical_position":1}' tabindex="0">
# <span class="js-estimated-monthly-payment-formatted-value-with-abr"></span> <svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#info"></use></svg>
# </a>
# </span>
# <div class="sds-tooltip__window js-tooltip-content" data-reveal-method="inline" id="tooltip-est-monthly-payment-1" role="tooltip">
# <p>
# Estimated monthly payment of  <span class="js-estimated-monthly-payment-formatted-value"></span>.
# Based on a vehicle price of $42,778, on a 72 month loan with 5.99% APR and a 20.00% down payment.
#       </p>
# <div class="sds-icon sds-icon--contain custom-close-tooltip" data-target="tooltip-est-monthly-payment-1">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-9957805ae2a418ae7507c2b0e074f33e.svg?vsn=d#close"></use></svg>
# </div>
# </div>
# </div>
# </span>
# <div class="vehicle-badging" data-click-intent-id="badges-explainer" data-contents='{"home_delivery_badge":true,"virtual_appointments_badge":true,"href_to_vdp":{"href_to_vdp":"/vehicledetail/37a40c0b-2c7c-4a5b-a532-b0838b31872b/?bodystyle=suv&amp;cpo_indicator=false&amp;customer_id=5343485&amp;intent_id=badges-explainer&amp;listing_id=37a40c0b-2c7c-4a5b-a532-b0838b31872b&amp;make=subaru&amp;model=outback&amp;model_year=2022&amp;msrp=42778&amp;price=42778&amp;sponsored%3F=false&amp;stock_type=new&amp;trim=touring+xt"}}' data-override-payload='{"bodystyle":"suv","cpo_indicator":false,"customer_id":"5343485","horizontal_position":null,"listing_id":"37a40c0b-2c7c-4a5b-a532-b0838b31872b","make":"subaru","model":"outback","model_year":"2022","msrp":"42778","price":"42778","results_page_number":1,"sponsored?":false,"stock_type":"new","trim":"touring xt","vertical_position":1,"web_page_type_from":"shopping/search-results"}' data-target="#sds-modal" data-toggle="expanda-modal" tabindex="0">
# <div class="sds-badge sds-badge--home-delivery">
# <span class="sds-badge__label">Home Delivery</span>
# </div>
# <div class="sds-badge sds-badge--virtual-appointments">
# <span class="sds-badge__label">Virtual Appointments</span>
# </div>
# </div>
# <div class="vehicle-links external-links">
# </div>
# <div class="vehicle-dealer">
# <div class="dealer-name">
# <strong>Patriot Subaru of NA</strong>
# </div>
# <div class="sds-rating">
# <span class="sds-rating__count">4.9</span>
# <div class="sds-rating__wrapper">
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# <span class="sds-rating__item sds-icon--filled">
# <svg fill="none" height="24" stroke="#000000" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <polygon points="12 2 15.09 8.26 22 9.27 17 14.14 18.18 21.02 12 17.77 5.82 21.02 7 14.14 2 9.27 8.91 8.26 12 2" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"></polygon>
# </svg>
# </span>
# </div>
# <span class="sds-rating__link sds-button-link">(83 reviews)</span>
# </div>
# <div class="miles-from hidden" data-qa="miles-from-user">
#        mi. from
#     </div>
# </div>
# </div>
# <div class="contact-buttons" id="37a40c0b-2c7c-4a5b-a532-b0838b31872b-lead-btns">
# <a class="sds-button--secondary contact-by-phone" data-activity-rule-type="custom" data-call-intent-id="srp-call-intent" data-index="1" data-linkname="dealer-phone-srp" data-listing-id="37a40c0b-2c7c-4a5b-a532-b0838b31872b" data-make="Subaru" data-model="Outback" data-phone-number="7742249468" data-trim="Touring XT" data-vin="4S4BTGPD4N3258072" data-year="2022" href="tel:+1-774-224-9468" id="dealer-phone-37a40c0b-2c7c-4a5b-a532-b0838b31872b" phx-hook="CallSourceDniSRPCallButton" phx-update="ignore">Call</a>
# <button class="sds-button lead-form-modal-button" data-activity-rule-type="custom" data-click-intent-id="open-lead-form-modal" data-dealer-customer-id="5343485" data-index="1" data-linkname="email-lead-form-srp" data-listing-id="37a40c0b-2c7c-4a5b-a532-b0838b31872b" data-override-payload='{"bodystyle":"SUV","customer_id":"5343485","listing_id":"37a40c0b-2c7c-4a5b-a532-b0838b31872b","make":"Subaru","model":"Outback","model_year":"2022","msrp":"42778","price":"42778","stock_type":"New","vertical_position":1}' data-sponsored="false" data-sponsored-invariant="false" data-sponsored-type="none" id="lead-form-email-37a40c0b-2c7c-4a5b-a532-b0838b31872b" phx-hook="ShowLeadForm">Check availability</button>
# <button class="sds-button lead-form-modal-button--desktop srp" data-activity-rule-type="custom" data-click-intent-id="open-lead-form-modal" data-dealer-customer-id="5343485" data-index="1" data-linkname="email-lead-form-srp" data-listing-id="37a40c0b-2c7c-4a5b-a532-b0838b31872b" data-override-payload='{"bodystyle":"SUV","customer_id":"5343485","listing_id":"37a40c0b-2c7c-4a5b-a532-b0838b31872b","make":"Subaru","model":"Outback","model_year":"2022","msrp":"42778","price":"42778","stock_type":"New","vertical_position":1}' data-sponsored="false" data-sponsored-invariant="false" data-sponsored-type="none" id="lead-form-37a40c0b-2c7c-4a5b-a532-b0838b31872b" phx-hook="ShowLeadForm">Check availability</button>
# </div>
# </div>
# </div>

# %% [markdown]
# # Name

# %%
results[0].find('h2').get_text()
# Out:
# '2022 Subaru Outback Touring XT'

# %% [markdown]
# # Price

# %%
results[0].find('span', class_ = "primary-price").get_text()
# Out:
# '$42,778'

# %% [markdown]
# # Rating

# %%
results[0].find('span', class_ = 'sds-rating__count').get_text()
# Out:
# '4.9'

# %% [markdown]
# # Dealer name

# %%
results[0].find('div', class_ = "dealer-name").get_text().strip()
# Out:
# 'Patriot Subaru of NA'

# %% [markdown]
# # Creating a For Loop

# %%
name = []
price = []
rating = []
dealer_name = []

for result in results:
    
    try:
    
         name.append(result.find('h2').get_text())
    
    except:
    
         name.append('n/a')
    
    try:
        
         price.append(result.find('span', class_ = "primary-price").get_text())
    
    except:
        
         price.append('n/a')    
    
    try:
        
         rating.append(result.find('span', class_ = 'sds-rating__count').get_text())
    
    except:
        
         rating.append('n/a')   
            
    try:        
            
            
        dealer_name.append(result.find('div', class_ = "dealer-name").get_text().strip()) 
    
    
    except:
        
        dealer_name.append('n/a')

# %%
dealer_name
# Out:
# ['Patriot Subaru of NA',
#  'Mastria Subaru',
#  'One Subaru of Hayward',
#  'Blaise Alexander Subaru of Lewistown',
#  'Mastria Subaru',
#  'East Hills Subaru of Sayville',
#  'One Subaru of Hayward',
#  'Wackerli Subaru B. A.',
#  'Van Chevrolet Cadillac',
#  'East Hills Subaru of Sayville',
#  'Brunswick Auto Mart',
#  'Subaru of Spokane',
#  'One Subaru of Hayward',
#  'Capitol Subaru',
#  'Paul Miller Subaru',
#  'Capitol Subaru',
#  'Subaru South Blvd',
#  'Chilson Subaru',
#  'Ken Ganley Subaru North Olmsted',
#  'One Subaru of Hayward']

# %% [markdown]
# # Creating a Pandas Dataframe

# %%
Cars = pd.DataFrame({'Name': name, 'Price': price, 'Rating': rating, 'Dealername': dealer_name})

# %%
Cars
# Out:
#                                    Name    Price Rating  \
# 0        2022 Subaru Outback Touring XT  $42,778    4.9
# 1           2022 Subaru Outback Premium  $32,646    4.9
# 2        2022 Subaru Outback Touring XT  $42,848    n/a
# 3        2022 Subaru Outback Touring XT  $40,357    n/a
# 4           2022 Subaru Outback Premium  $32,844    4.9
# 5           2022 Subaru Outback Touring  $40,624    n/a
# 6        2022 Subaru Outback Touring XT  $42,772    n/a
# 7           2022 Subaru Outback Premium  $34,156    4.8
# 8           2022 Subaru Outback Premium  $34,722    4.6
# 9        2022 Subaru Outback Touring XT  $43,455    n/a
# 10       2022 Subaru Outback Limited XT  $40,822    4.6
# 11       2022 Subaru Outback Limited XT  $41,235    4.8
# 12          2022 Subaru Outback Limited  $38,543    n/a
# 13  2022 Subaru Outback Onyx Edition XT  $37,020    4.1
# 14       2022 Subaru Outback Wilderness  $42,456    4.7
# 15       2022 Subaru Outback Touring XT  $42,348    4.1
# 16          2022 Subaru Outback Premium  $32,744    4.5
# 17          2022 Subaru Outback Premium  $35,395    4.5
# 18       2022 Subaru Outback Touring XT  $45,772    4.8
# 19       2022 Subaru Outback Limited XT  $40,898    n/a
#
#                               Dealername
# 0                   Patriot Subaru of NA
# 1                         Mastria Subaru
# 2                  One Subaru of Hayward
# 3   Blaise Alexander Subaru of Lewistown
# 4                         Mastria Subaru
# 5          East Hills Subaru of Sayville
# 6                  One Subaru of Hayward
# 7                  Wackerli Subaru B. A.
# 8                 Van Chevrolet Cadillac
# 9          East Hills Subaru of Sayville
# 10                   Brunswick Auto Mart
# 11                     Subaru of Spokane
# 12                 One Subaru of Hayward
# 13                        Capitol Subaru
# 14                    Paul Miller Subaru
# 15                        Capitol Subaru
# 16                     Subaru South Blvd
# 17                        Chilson Subaru
# 18       Ken Ganley Subaru North Olmsted
# 19                 One Subaru of Hayward

# %% [markdown]
# # Output in Excel

# %%
Cars.to_excel('Cars_data.xlsx', index = False)

# %% [markdown]
# # Finish
